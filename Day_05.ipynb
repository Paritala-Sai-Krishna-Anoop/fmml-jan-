# %% [markdown]
# <a href="https://colab.research.google.com/github/Paritala-Sai-Krishna-Anoop/fmml-jan-/blob/main/Day_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2 as cv

# %%
from google.colab import files

# %%
orig_image = cv.imread('paulie-walnuts.jpg', 0)

# %%
orig_image.shape
# Out:
# (400, 710)

# %%
cv.imwrite('gray-blur.png', orig_image)
# Out:
# True

# %%
plt.imshow(orig_image)

# %%
portion_image = orig_image[190:290, 250:350]

# %%
plt.imshow(portion_image)

# %%
blurred_image = cv.blur(portion_image, (10, 10))

# %%
plt.imshow(blurred_image)

# %%
blurred_image.shape
# Out:
# (100, 100)

# %%
orig_image[190:290, 250:350] = blurred_image

# %%
plt.imshow(orig_image)

# %%
cv.imwrite('blurred_image.png', orig_image)
# Out:
# True
